# %% [markdown]
# <img height="100" src="logotmg.png" width="900" alt="Talia Morchi" id="tmg_logo" title="Data Analyst Course">
# <center><h1><u>Welcome to the python for data analysis course </u></h1></center><center><h2>Class 6</h2></center>

# %% [markdown]
# ## Info
# https://www.oracletutorial.com/python-oracle/

# %% [markdown]
# ## How to Connect Python to Oracle Database using cx_Oracle

# %% [markdown]
# #### Step 1: Install the cx_Oracle package

# %%
# Installing Oracle 
pip install cx_Oracle

# %% [markdown]
# #### Step 2: Retrieve the connection information

# %%
# Import libraries
import cx_Oracle
import config

# %%
# Set connection info
conn = cx_Oracle.connect(config.username,
                         config.password,
                         config.dsn,
                         encoding=config.encoding)

# %% [markdown]
# #### From here same as MSSQL

# %%
# Create cursor object
cursor = conn.cursor()

# %%
# write sql query
sql = 'Query text'

# %%
cursor.execute (query)

# %%
res = cursor.fetchall()

# %%
# write functionality with the data received in res

# %%
# Close connections and cursor
cursor.close()
conn.close()
