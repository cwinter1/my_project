# %% [markdown]
# <img height="100" src="logotmg.png" width="900" alt="Talia Morchi" id="tmg_logo" title="Data Analyst Course">
# <center><h1><u>Welcome to the python for data analysis course </u></h1></center><center><h2>Class 2 + 3</h2></center>

# %% [markdown]
# ## Pandas

# %%
# Import Pandas library
import pandas as pd

# %% [markdown]
# ## Import data
#
# Import data from csv file.
# It is recommended to save the file in the same folder as your notebook
#
# If saved in the same folder: 'file_name.csv'
#
# If not saved in the same folder: r'full_path\file_name.csv':
#
#         pd.read_csv (r'C:\Talia_Study\Data_Sets\netflix_titles.csv')

# %%
# Import data as DataFrame
pd.read_csv ('hotel_bookings.csv')
# Out:
#         reservation_no         hotel  is_canceled  lead_time  \
# 0                12603  Resort Hotel            0        342
# 1                12604  Resort Hotel            0        737
# 2                12605  Resort Hotel            0          7
# 3                12606  Resort Hotel            0         13
# 4                12607  Resort Hotel            0         14
# ...                ...           ...          ...        ...
# 119385          131988    City Hotel            0         23
# 119386          131989    City Hotel            0        102
# 119387          131990    City Hotel            0         34
# 119388          131991    City Hotel            0        109
# 119389          131992    City Hotel            0        205
#
#         arrival_date_year arrival_date_month  arrival_date_week_number  \
# 0                    2015               July                        27
# 1                    2015               July                        27
# ...

# %%
# Import only one column as Pandas Series
# >> Check the differance with type () function
# >> index is automatically running number starts with 0

s = pd.read_csv ('hotel_bookings.csv', usecols=['arrival_date_month'], squeeze=True)

# %%
# Create another series from integer value
# Changing index to values in spacific column
int_s = pd.read_csv ('hotel_bookings.csv',usecols=['stays_in_week_nights','hotel'], 
                     squeeze=True, index_col='hotel')

# %% [markdown]
# ## Attributes
#
# With Attributes we can know information about the series components

# %%
# Array with all the values in the Series
s.values
# Out:
# array(['July', 'July', 'July', ..., 'August', 'August', 'August'],
#       dtype=object)

# %%
# Description of the indexes
s.index
# Out:
# RangeIndex(start=0, stop=119390, step=1)

# %%
# Data type of the objects in the Series
s.dtypes
# Out:
# dtype('O')

# %% [markdown]
# ## Viewing and Inspecting data

# %% [markdown]
# #### List of all methods and attributes available

# %%
# List of all the methods and attributes for this object
dir (s)
# Out:
# ['T',
#  '_AXIS_ALIASES',
#  '_AXIS_IALIASES',
#  '_AXIS_LEN',
#  '_AXIS_NAMES',
#  '_AXIS_NUMBERS',
#  '_AXIS_ORDERS',
#  '_AXIS_REVERSED',
#  '_HANDLED_TYPES',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__annotations__',
#  '__array__',
#  '__array_priority__',
#  '__array_ufunc__',
#  '__array_wrap__',
#  '__bool__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__div__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__float__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__int__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__long__',
# ...

# %% [markdown]
# #### Basic info

# %%
# Show the content of first x rows
s.head(3)
# Out:
# 0    July
# 1    July
# 2    July
# Name: arrival_date_month, dtype: object

# %%
# Show the content of last x rows
s.tail(3)
# Out:
# 119387    August
# 119388    August
# 119389    August
# Name: arrival_date_month, dtype: object

# %%
# max value in the Series
int_s.max()
# Out:
# 50

# %%
# Return the row number of the maximum value
int_s.argmax()
# Out:
# 14038

# %%
# Return the index lable of the maximum value
int_s.idxmax()
# Out:
# 'Resort Hotel'

# %%
# min value in the Series
int_s.min()
# Out:
# 0

# %%
# Return the row number of the minimum value
int_s.argmin()
# Out:
# 0

# %%
# Return the index lable of the minimum value
int_s.idxmin()
# Out:
# 'Resort Hotel'

# %%
# Lenght od the Series
len (s)
# Out:
# 119390

# %%
# Return boolean if values in the object are unique
s.is_unique
# Out:
# False

# %%
# Generate descriptive statistics
# >> check for both s and int_s
s.describe()
# Out:
# count     119390
# unique        12
# top       August
# freq       13877
# Name: arrival_date_month, dtype: object

# %%
# Get Series name
# >> can change Series name
s.name
# Out:
# 'arrival_date_month'

# %%
# Return a Series containing counts of unique values.
# Use for categorial field
# Parameter: dropna=True (remove NaN), dropna=False (Don't remove NaN)
s.value_counts()
# Out:
# August       13877
# July         12661
# May          11791
# October      11160
# April        11089
# June         10939
# September    10508
# March         9794
# February      8068
# November      6794
# December      6780
# January       5929
# Name: arrival_date_month, dtype: int64

# %% [markdown]
# #### Sort

# %%
# Sort Series according to Series values
# >> parameters: ascending=False, inplace=True
s.sort_values ()
# Out:
# 87641        April
# 87091        April
# 87090        April
# 87089        April
# 87088        April
#            ...
# 8398     September
# 8397     September
# 8396     September
# 8404     September
# 98043    September
# Name: arrival_date_month, Length: 119390, dtype: object

# %%
# sort Series according to Series index
# parameters: ascending=False, inplace=True
s.sort_index ()
# Out:
# 0           July
# 1           July
# 2           July
# 3           July
# 4           July
#            ...
# 119385    August
# 119386    August
# 119387    August
# 119388    August
# 119389    August
# Name: arrival_date_month, Length: 119390, dtype: object

# %% [markdown]
# #### In keyword

# %%
# Check if value is in the Series values
# >> check if value is in the index: 34 in s
'April' in s.values
# Out:
# True

# %% [markdown]
# #### Locate data

# %%
# Return the row with the specified index lable or the location
# >> default value: default='Not Found'
int_s['Resort Hotel']
# Out:
# Resort Hotel     0
# Resort Hotel     0
# Resort Hotel     1
# Resort Hotel     1
# Resort Hotel     2
#                 ..
# Resort Hotel     8
# Resort Hotel     9
# Resort Hotel    10
# Resort Hotel    10
# Resort Hotel    10
# Name: stays_in_week_nights, Length: 40060, dtype: int64

# %%
# Returns the rows in the spacified *locations*: [start:stop:step]
s.iloc[840:845]
# int_s.iloc[840:845]
# Out:
# 840      July
# 841      July
# 842    August
# 843    August
# 844    August
# Name: arrival_date_month, dtype: object

# %%
# Returns the rows that their *lable index* is in the range [start:stop:step]
s.loc[840:843]
# int_s.loc['Resort Hotel']
# Out:
# 840      July
# 841      July
# 842    August
# 843    August
# Name: arrival_date_month, dtype: object

# %%
# Returns the rows in the locations list
s[  [1,840, 844, 2400]  ]
# Out:
# 1          July
# 840        July
# 844      August
# 2400    October
# Name: arrival_date_month, dtype: object

# %% [markdown]
# <img height="100" src="time_to_practice.png" width="200" alt="Hands on" id="prc_time" title="Data Analyst Course">
# <center><h1>Class Practice 2.2</h1></center>

# %% [markdown]
# 1. From the hotel_bookings.csv file import column 'reservation_no' as index and 'stays_in_week_nights' into series name: 'ex_nights'
#
# 2. How many week nights were booked from the hotel?
#
# 3. What is the maximum week nights ordered?
#
# 4. What is the reservation number of the maximum week nights ordered?
#
# 5. Locate the reservation number you found in the previus section and check if you were correct
#
# 6. How many reservation ordered 15 week nights?
#
# 7. What are the top 3 amount of nights ordered?
#
# 8. What are the average nights ordered?

# %% [markdown]
# ## DataFrame
#
# Pandas matrix data structure

# %%
# Import data as DataFrame
df = pd.read_csv ('hotel_bookings.csv')

# %%
# Show top n rows
df.head(3)
# Out:
#    reservation_no         hotel  is_canceled  lead_time  arrival_date_year  \
# 0           12603  Resort Hotel            0        342               2015
# 1           12604  Resort Hotel            0        737               2015
# 2           12605  Resort Hotel            0          7               2015
#
#   arrival_date_month  arrival_date_week_number  arrival_date_day_of_month  \
# 0               July                        27                          1
# 1               July                        27                          1
# 2               July                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  ...  deposit_type  agent  \
# 0                        0                     0  ...    No Deposit    NaN
# 1                        0                     0  ...    No Deposit    NaN
# 2                        0                     1  ...    No Deposit    NaN
#
#    company days_in_waiting_list customer_type   adr  \
# ...

# %% [markdown]
# #### Basic information
#
# Most of the attributes and methods are working for both DataFrame and Series

# %%
# Return a tuple representing the dimensionality of the DataFrame
df.shape
# Out:
# (119390, 33)

# %%
# Generate descriptive statistics
df.describe ()
# Out:
#        reservation_no    is_canceled      lead_time  arrival_date_year  \
# count   119390.000000  119390.000000  119390.000000      119390.000000
# mean     72297.500000       0.370416     104.011416        2016.156554
# std      34465.068657       0.482918     106.863097           0.707476
# min      12603.000000       0.000000       0.000000        2015.000000
# 25%      42450.250000       0.000000      18.000000        2016.000000
# 50%      72297.500000       0.000000      69.000000        2016.000000
# 75%     102144.750000       1.000000     160.000000        2017.000000
# max     131992.000000       1.000000     737.000000        2017.000000
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count             119390.000000              119390.000000
# mean                  27.165173                  15.798241
# std                   13.605138                   8.780829
# min                    1.000000                   1.000000
# ...

# %%
# Print a concise summary of a DataFram
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 33 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   reservation_no                  119390 non-null  int64
#  1   hotel                           119390 non-null  object
#  2   is_canceled                     119390 non-null  int64
#  3   lead_time                       119390 non-null  int64
#  4   arrival_date_year               119390 non-null  int64
#  5   arrival_date_month              119390 non-null  object
#  6   arrival_date_week_number        119390 non-null  int64
#  7   arrival_date_day_of_month       119390 non-null  int64
#  8   stays_in_weekend_nights         119390 non-null  int64
#  9   stays_in_week_nights            119390 non-null  int64
#  10  adults                          119390 non-null  int64
#  11  children                        119386 non-null  float64
# ...

# %%
# Return all the keys (all the columns header)
df.keys()
# Out:
# RangeIndex(start=0, stop=119390, step=1)

# %% [markdown]
# #### Show specific data

# %%
# Show one column from the DataFrame
df['country']
# Out:
# 0         PRT
# 1         PRT
# 2         GBR
# 3         GBR
# 4         GBR
#          ...
# 119385    BEL
# 119386    FRA
# 119387    DEU
# 119388    GBR
# 119389    DEU
# Name: country, Length: 119390, dtype: object

# %% [markdown]
# #### Question: What is the average number of nights that customers book
#
# * descriptive statistics on the nights ordered in week / weekend
#
# * Are there any orders that have been canceled, or not executed?

# %%
# First lets view only the data that is relevant for us
# Shows only the columns that are in the list
sdf = df[     ['hotel', 'arrival_date_month', 'stays_in_weekend_nights','stays_in_week_nights', 'reservation_status']    ]

# %%
# Lets check what are the values in column reservation_status
df['reservation_status'].value_counts()
# Out:
# Check-Out    75166
# Canceled     43017
# No-Show       1207
# Name: reservation_status, dtype: int64

# %%
# Filter the irrelevant records out of the table
sdf = sdf [sdf['reservation_status'] == 'Check-Out']
# Out:
#                hotel arrival_date_month  stays_in_weekend_nights  \
# 0       Resort Hotel               July                        0
# 1       Resort Hotel               July                        0
# 2       Resort Hotel               July                        0
# 3       Resort Hotel               July                        0
# 4       Resort Hotel               July                        0
# ...              ...                ...                      ...
# 119385    City Hotel             August                        2
# 119386    City Hotel             August                        2
# 119387    City Hotel             August                        2
# 119388    City Hotel             August                        2
# 119389    City Hotel             August                        2
#
#         stays_in_week_nights reservation_status
# 0                          0          Check-Out
# 1                          0          Check-Out
# ...

# %%
# Generate descriptive statistics on the remain records
sdf.describe()
# Out:
#        stays_in_weekend_nights  stays_in_week_nights
# count             75166.000000          75166.000000
# mean                  0.928971              2.464053
# std                   0.993371              1.924803
# min                   0.000000              0.000000
# 25%                   0.000000              1.000000
# 50%                   1.000000              2.000000
# 75%                   2.000000              3.000000
# max                  19.000000             50.000000

# %%
# Sort the values
# >> It is not possible to get correct information because there are two columns with relevant data 
# >> should merged data into one new column
sdf.sort_values('stays_in_week_nights', ascending=False)
# Out:
#                hotel arrival_date_month  stays_in_weekend_nights  \
# 14038   Resort Hotel               July                       19
# 14037   Resort Hotel             August                       18
# 101794    City Hotel          September                       16
# 33924   Resort Hotel            January                       16
# 88017     City Hotel              March                       14
# ...              ...                ...                      ...
# 36831   Resort Hotel                May                        2
# 36832   Resort Hotel                May                        2
# 36833   Resort Hotel                May                        2
# 36834   Resort Hotel                May                        1
# 0       Resort Hotel               July                        0
#
#         stays_in_week_nights reservation_status  total_nights
# 14038                     50          Check-Out            69
# ...

# %% [markdown]
# #### Add new column to DataFrame

# %%
# Create new column for total_nights and update its value
sdf['total_nights'] = sdf['stays_in_weekend_nights'] + sdf['stays_in_week_nights']

# %%
# descriptive statistics on the updated DataFrame
# >> on specific column ['total_nights']
sdf.describe()
# Out:
# count    75166.000000
# mean         3.393023
# std          2.577671
# min          0.000000
# 25%          2.000000
# 50%          3.000000
# 75%          4.000000
# max         69.000000
# Name: total_nights, dtype: float64

# %% [markdown]
# <img height="100" src="time_to_practice.png" width="200" alt="Hands on" id="prc_time" title="Data Analyst Course">
# <center><h1>Class Practice 2.3</h1></center>

# %% [markdown]
# 1. Import hotel_bookings.csv file into DataFrame name: 'df_hotel'
#
#
# 2. How many orders there are for each hotel?
#
#
# 3. Filter the records (rows), and show only the records whose arrival_date_month was July?
#
#
# 4. Continuing from the previous section, sort the results by 'adults' column (number of adults in the room) descending
#
#
# 5. **Advanced Exercise** -  Continuing from the previous section, show only columns: 'reservation_no', 'arrival_date_month', 'asults'

# %% [markdown]
# =========================================================================================

# %% [markdown]
# #### Pactice 2.2 - Solution
# 1. From the hotel_bookings.csv file import column 'reservation_no' as index and 'stays_in_week_nights' into series name: 'ex_nights'
#
#
# 2. How many week nights were booked from the hotel?
#
#
# 3. What is the maximum week nights ordered?
#
#
# 4. What is the reservation number of the maximum week nights ordered?
#
#
# 5. Locate the reservation number you found in the previus section and check if you were correct
#
#
# 6. How many reservation ordered 15 week nights?
#
#
# 7. What are the top 3 amount of nights ordered?
#
#
# 8. What are the average nights ordered?

# %%
# 1
ex_nights = pd.read_csv ('hotel_bookings.csv', 
                         usecols = ['reservation_no', 'stays_in_week_nights'],
                        index_col = 'reservation_no',
                        squeeze=True)
ex_nights
# Out:
# reservation_no
# 12603     0
# 12604     0
# 12605     1
# 12606     1
# 12607     2
#          ..
# 131988    5
# 131989    5
# 131990    5
# 131991    5
# 131992    7
# Name: stays_in_week_nights, Length: 119390, dtype: int64

# %%
# 2
ex_nights.sum ()
# Out:
# 298511

# %%
# 3
ex_nights.max ()
# Out:
# 50

# %%
# 4
ex_nights.idxmax()
# Out:
# 26641

# %%
# 5
# Option 1
ex_nights.loc[26641]
# Option 2
ex_nights[26641]
# Out:
# 50

# %%
# 6
ex_nights[ ex_nights == 15 ].count()
# Out:
# 85

# %%
# 7
ex_nights.value_counts().head (3)
# Out:
# 2    33684
# 1    30310
# 3    22258
# Name: stays_in_week_nights, dtype: int64

# %%
# 8
ex_nights.mean()
# Out:
# 2.500301532791691

# %% [markdown]
# #### Pactice 2.3 - Solution
# 1. Import hotel_bookings.csv file into DataFrame name: 'df_hotel'
#
#
# 2. How many orders there are for each hotel?
#
#
# 3. Filter the records (rows), and show only the records whose arrival_date_month was July?
#
#
# 4. Continuing from the previous section, sort the results by 'adults' column (number of adults in the room) descending
#
#
# 5. **Advanced Exercise** -  Continuing from the previous section, show only columns: 'reservation_no', 'arrival_date_month', 'asults'

# %%
# 1
df_hotel = pd.read_csv('hotel_bookings.csv')
df_hotel
# Out:
#         reservation_no         hotel  is_canceled  lead_time  \
# 0                12603  Resort Hotel            0        342
# 1                12604  Resort Hotel            0        737
# 2                12605  Resort Hotel            0          7
# 3                12606  Resort Hotel            0         13
# 4                12607  Resort Hotel            0         14
# ...                ...           ...          ...        ...
# 119385          131988    City Hotel            0         23
# 119386          131989    City Hotel            0        102
# 119387          131990    City Hotel            0         34
# 119388          131991    City Hotel            0        109
# 119389          131992    City Hotel            0        205
#
#         arrival_date_year arrival_date_month  arrival_date_week_number  \
# 0                    2015               July                        27
# 1                    2015               July                        27
# ...

# %%
# 2
df_hotel['hotel'].value_counts()
# Out:
# City Hotel      79330
# Resort Hotel    40060
# Name: hotel, dtype: int64

# %%
# 3
mask = df_hotel['arrival_date_month'] == 'July'
df_hotel[mask]
# Out:
#         reservation_no         hotel  is_canceled  lead_time  \
# 0                12603  Resort Hotel            0        342
# 1                12604  Resort Hotel            0        737
# 2                12605  Resort Hotel            0          7
# 3                12606  Resort Hotel            0         13
# 4                12607  Resort Hotel            0         14
# ...                ...           ...          ...        ...
# 117737          130340    City Hotel            0        158
# 117772          130375    City Hotel            0        158
# 117821          130424    City Hotel            0        308
# 117822          130425    City Hotel            0        308
# 117829          130432    City Hotel            0        203
#
#         arrival_date_year arrival_date_month  arrival_date_week_number  \
# 0                    2015               July                        27
# 1                    2015               July                        27
# ...

# %%
# 4
mask = df_hotel['arrival_date_month'] == 'July'
df_hotel[mask].sort_values('adults', ascending=False)
# Out:
#         reservation_no         hotel  is_canceled  lead_time  \
# 116395          128998    City Hotel            0         84
# 94415           107018    City Hotel            0        127
# 93894           106497    City Hotel            0         45
# 26306            38909  Resort Hotel            0        130
# 13027            25630  Resort Hotel            1        318
# ...                ...           ...          ...        ...
# 54000            66603    City Hotel            0        193
# 71512            84115    City Hotel            1        315
# 54887            67490    City Hotel            0        236
# 54888            67491    City Hotel            1        225
# 93754           106357    City Hotel            0          0
#
#         arrival_date_year arrival_date_month  arrival_date_week_number  \
# 116395               2017               July                        29
# 94415                2016               July                        32
# ...

# %%
# 5
mask = df_hotel['arrival_date_month'] == 'July'
# Option 1:
df_hotel[mask].sort_values('adults', ascending=False)[['reservation_no', 'arrival_date_month', 'adults']]

# Option 2
df_hotel[mask][['reservation_no', 'arrival_date_month', 'adults']].sort_values('adults', ascending=False)

# Option 3
cols = ['reservation_no', 'arrival_date_month', 'adults']
df_hotel[mask][cols].sort_values('adults', ascending=False)
# Out:
#         reservation_no arrival_date_month  adults
# 116395          128998               July       4
# 94415           107018               July       4
# 93894           106497               July       4
# 26306            38909               July       4
# 13027            25630               July       4
# ...                ...                ...     ...
# 54000            66603               July       0
# 71512            84115               July       0
# 54887            67490               July       0
# 54888            67491               July       0
# 93754           106357               July       0
#
# [12661 rows x 3 columns]
